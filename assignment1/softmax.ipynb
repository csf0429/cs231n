# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
  """
  Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
  it for the linear classifier. These are the same steps as we used for the
  SVM, but condensed to a single function.  
  """
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_dev, replace=False)
  X_dev = X_train[mask]
  y_dev = y_train[mask]
  
  # Preprocessing: reshape the image data into rows
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
  
  # Normalize the data: subtract the mean image
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_dev -= mean_image
  
  # add bias dimension and transform into columns
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'dev data shape: ', X_dev.shape
print 'dev labels shape: ', y_dev.shape
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))
# Out:
# loss: 2.354849
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *We have 10 classes. By the probabilistic cross-entropy loss interpretation of Softmax, we expect the average probability of each class to be ~0.1 (they are all a priori just as likely). We're using the -log of this as our loss.*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.948210 analytic: 0.948210, relative error: 5.020465e-08
# numerical: -0.938132 analytic: -0.938132, relative error: 5.442211e-08
# numerical: 1.540427 analytic: 1.540427, relative error: 1.063887e-07
# numerical: -1.370822 analytic: -1.370822, relative error: 4.108895e-08
# numerical: 0.536795 analytic: 0.536795, relative error: 9.956395e-08
# numerical: -1.644625 analytic: -1.644625, relative error: 4.796086e-10
# numerical: 2.019790 analytic: 2.019789, relative error: 1.881576e-08
# numerical: -0.764828 analytic: -0.764828, relative error: 2.399824e-08
# numerical: -1.163074 analytic: -1.163074, relative error: 4.414377e-08
# numerical: 1.675016 analytic: 1.675016, relative error: 3.435695e-08
# numerical: 0.083871 analytic: 0.083871, relative error: 7.829962e-08
# numerical: -3.464327 analytic: -3.464327, relative error: 1.413914e-08
# numerical: -2.245380 analytic: -2.245380, relative error: 1.214370e-08
# numerical: 2.485631 analytic: 2.485631, relative error: 2.468919e-08
# numerical: -2.805716 analytic: -2.805716, relative error: 1.017937e-08
# numerical: -0.175670 analytic: -0.175670, relative error: 4.605785e-07
# numerical: -2.228019 analytic: -2.228019, relative error: 2.569247e-08
# numerical: -1.057557 analytic: -1.057557, relative error: 6.386974e-09
# numerical: 2.871948 analytic: 2.871948, relative error: 2.419155e-08
# numerical: 0.523301 analytic: 0.523301, relative error: 1.343625e-07

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'Loss difference: %f' % np.abs(loss_naive - loss_vectorized)
print 'Gradient difference: %f' % grad_difference
# Out:
# naive loss: 2.354849e+00 computed in 0.165414s
# vectorized loss: 2.354849e+00 computed in 0.007768s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 2e-7, 3e-7, 5e-5, 8e-7]
regularization_strengths = [1e4, 2e4, 3e4, 4e4, 5e4, 6e4, 7e4, 8e4, 1e5]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr in learning_rates:
    for rs in regularization_strengths:
        softmax = Softmax()
        loss = softmax.train(X_train, y_train, learning_rate=lr, reg=rs,
                      num_iters=2000,batch_size=200, verbose=True)
        y_train_pred = softmax.predict(X_train)
        train_accuracy = np.mean(y_train == y_train_pred)
        y_val_pred = softmax.predict(X_val)
        val_accuracy = np.mean(y_val == y_val_pred)
        
        results[(lr,rs)]= (train_accuracy, val_accuracy)
        if val_accuracy > best_val:
            best_val = val_accuracy
            best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# iteration 0 / 2000: loss 159.865213
# iteration 100 / 2000: loss 130.178404
# iteration 200 / 2000: loss 106.604711
# iteration 300 / 2000: loss 87.488552
# iteration 400 / 2000: loss 71.636343
# iteration 500 / 2000: loss 58.750939
# iteration 600 / 2000: loss 48.493918
# iteration 700 / 2000: loss 39.745908
# iteration 800 / 2000: loss 33.030551
# iteration 900 / 2000: loss 27.361922
# iteration 1000 / 2000: loss 22.694005
# iteration 1100 / 2000: loss 18.922452
# iteration 1200 / 2000: loss 15.878175
# iteration 1300 / 2000: loss 13.141943
# iteration 1400 / 2000: loss 11.209968
# iteration 1500 / 2000: loss 9.525677
# iteration 1600 / 2000: loss 8.146233
# iteration 1700 / 2000: loss 7.045304
# iteration 1800 / 2000: loss 6.020003
# iteration 1900 / 2000: loss 5.290536
# iteration 0 / 2000: loss 312.007431
# iteration 100 / 2000: loss 208.067889
# iteration 200 / 2000: loss 139.497298
# iteration 300 / 2000: loss 93.763764
# iteration 400 / 2000: loss 63.459945
# iteration 500 / 2000: loss 42.974229
# iteration 600 / 2000: loss 29.423467
# iteration 700 / 2000: loss 20.409473
# iteration 800 / 2000: loss 14.227263
# iteration 900 / 2000: loss 10.277106
# iteration 1000 / 2000: loss 7.522891
# iteration 1100 / 2000: loss 5.681136
# iteration 1200 / 2000: loss 4.477716
# iteration 1300 / 2000: loss 3.649204
# iteration 1400 / 2000: loss 3.098563
# iteration 1500 / 2000: loss 2.727187
# iteration 1600 / 2000: loss 2.513627
# iteration 1700 / 2000: loss 2.317540
# iteration 1800 / 2000: loss 2.167814
# iteration 1900 / 2000: loss 2.103970
# iteration 0 / 2000: loss 466.502576
# iteration 100 / 2000: loss 254.726184
# iteration 200 / 2000: loss 140.099729
# iteration 300 / 2000: loss 77.470239
# iteration 400 / 2000: loss 43.424768
# iteration 500 / 2000: loss 24.648794
# iteration 600 / 2000: loss 14.419586
# iteration 700 / 2000: loss 8.804591
# iteration 800 / 2000: loss 5.740046
# iteration 900 / 2000: loss 4.069738
# iteration 1000 / 2000: loss 3.142286
# iteration 1100 / 2000: loss 2.636137
# iteration 1200 / 2000: loss 2.399809
# iteration 1300 / 2000: loss 2.194585
# iteration 1400 / 2000: loss 2.154369
# iteration 1500 / 2000: loss 2.047889
# iteration 1600 / 2000: loss 2.084436
# iteration 1700 / 2000: loss 2.073850
# iteration 1800 / 2000: loss 2.075184
# iteration 1900 / 2000: loss 2.063473
# iteration 0 / 2000: loss 622.265472
# iteration 100 / 2000: loss 278.948370
# iteration 200 / 2000: loss 125.817076
# iteration 300 / 2000: loss 57.457301
# iteration 400 / 2000: loss 26.762459
# iteration 500 / 2000: loss 13.190671
# iteration 600 / 2000: loss 7.034045
# iteration 700 / 2000: loss 4.262533
# iteration 800 / 2000: loss 3.049518
# iteration 900 / 2000: loss 2.483628
# iteration 1000 / 2000: loss 2.239948
# iteration 1100 / 2000: loss 2.073398
# iteration 1200 / 2000: loss 2.132516
# iteration 1300 / 2000: loss 2.128510
# iteration 1400 / 2000: loss 2.145857
# iteration 1500 / 2000: loss 2.068927
# iteration 1600 / 2000: loss 2.010287
# iteration 1700 / 2000: loss 2.056026
# iteration 1800 / 2000: loss 2.058430
# iteration 1900 / 2000: loss 2.061028
# iteration 0 / 2000: loss 761.766122
# iteration 100 / 2000: loss 279.523313
# iteration 200 / 2000: loss 103.719346
# iteration 300 / 2000: loss 39.208933
# iteration 400 / 2000: loss 15.580869
# iteration 500 / 2000: loss 7.145805
# iteration 600 / 2000: loss 3.928412
# iteration 700 / 2000: loss 2.742304
# iteration 800 / 2000: loss 2.307555
# iteration 900 / 2000: loss 2.137528
# iteration 1000 / 2000: loss 2.124945
# iteration 1100 / 2000: loss 2.103258
# iteration 1200 / 2000: loss 2.108823
# iteration 1300 / 2000: loss 2.067889
# iteration 1400 / 2000: loss 2.081365
# iteration 1500 / 2000: loss 2.102586
# iteration 1600 / 2000: loss 2.102721
# iteration 1700 / 2000: loss 2.118430
# iteration 1800 / 2000: loss 2.067031
# iteration 1900 / 2000: loss 2.121492
# iteration 0 / 2000: loss 939.653399
# iteration 100 / 2000: loss 282.031881
# iteration 200 / 2000: loss 85.895366
# iteration 300 / 2000: loss 27.193463
# iteration 400 / 2000: loss 9.568990
# iteration 500 / 2000: loss 4.368552
# iteration 600 / 2000: loss 2.730004
# iteration 700 / 2000: loss 2.312135
# iteration 800 / 2000: loss 2.097357
# iteration 900 / 2000: loss 2.131145
# iteration 1000 / 2000: loss 2.128573
# iteration 1100 / 2000: loss 2.095428
# iteration 1200 / 2000: loss 2.101954
# iteration 1300 / 2000: loss 2.147129
# iteration 1400 / 2000: loss 2.105356
# iteration 1500 / 2000: loss 2.096005
# iteration 1600 / 2000: loss 2.128022
# iteration 1700 / 2000: loss 2.123628
# iteration 1800 / 2000: loss 2.124751
# iteration 1900 / 2000: loss 2.092338
# iteration 0 / 2000: loss 1071.962339
# iteration 100 / 2000: loss 263.764118
# iteration 200 / 2000: loss 66.167104
# iteration 300 / 2000: loss 17.778064
# iteration 400 / 2000: loss 5.930949
# iteration 500 / 2000: loss 3.055233
# iteration 600 / 2000: loss 2.346004
# iteration 700 / 2000: loss 2.119312
# iteration 800 / 2000: loss 2.153138
# iteration 900 / 2000: loss 2.118573
# iteration 1000 / 2000: loss 2.108864
# iteration 1100 / 2000: loss 2.090826
# iteration 1200 / 2000: loss 2.137137
# iteration 1300 / 2000: loss 2.108798
# iteration 1400 / 2000: loss 2.098681
# iteration 1500 / 2000: loss 2.118964
# iteration 1600 / 2000: loss 2.078025
# iteration 1700 / 2000: loss 2.095077
# iteration 1800 / 2000: loss 2.074210
# iteration 1900 / 2000: loss 2.141976
# iteration 0 / 2000: loss 1239.148530
# iteration 100 / 2000: loss 248.750998
# iteration 200 / 2000: loss 51.490161
# iteration 300 / 2000: loss 11.958416
# iteration 400 / 2000: loss 4.103385
# iteration 500 / 2000: loss 2.451470
# iteration 600 / 2000: loss 2.228160
# iteration 700 / 2000: loss 2.153198
# iteration 800 / 2000: loss 2.148098
# iteration 900 / 2000: loss 2.173957
# iteration 1000 / 2000: loss 2.113707
# iteration 1100 / 2000: loss 2.182927
# iteration 1200 / 2000: loss 2.160826
# iteration 1300 / 2000: loss 2.122284
# iteration 1400 / 2000: loss 2.141489
# iteration 1500 / 2000: loss 2.095317
# iteration 1600 / 2000: loss 2.132348
# iteration 1700 / 2000: loss 2.143391
# iteration 1800 / 2000: loss 2.161033
# iteration 1900 / 2000: loss 2.120776
# iteration 0 / 2000: loss 1557.140825
# iteration 100 / 2000: loss 209.558676
# iteration 200 / 2000: loss 29.908387
# iteration 300 / 2000: loss 5.831542
# iteration 400 / 2000: loss 2.673499
# iteration 500 / 2000: loss 2.191650
# iteration 600 / 2000: loss 2.165492
# iteration 700 / 2000: loss 2.104455
# iteration 800 / 2000: loss 2.081503
# iteration 900 / 2000: loss 2.180121
# iteration 1000 / 2000: loss 2.135140
# iteration 1100 / 2000: loss 2.161772
# iteration 1200 / 2000: loss 2.145569
# iteration 1300 / 2000: loss 2.145155
# iteration 1400 / 2000: loss 2.166721
# iteration 1500 / 2000: loss 2.116310
# iteration 1600 / 2000: loss 2.130496
# iteration 1700 / 2000: loss 2.142094
# iteration 1800 / 2000: loss 2.137178
# iteration 1900 / 2000: loss 2.154106
# iteration 0 / 2000: loss 159.493228
# iteration 100 / 2000: loss 106.030026
# iteration 200 / 2000: loss 71.246528
# iteration 300 / 2000: loss 48.196665
# iteration 400 / 2000: loss 32.782845
# iteration 500 / 2000: loss 22.372945
# iteration 600 / 2000: loss 15.651046
# iteration 700 / 2000: loss 11.141558
# iteration 800 / 2000: loss 8.011414
# iteration 900 / 2000: loss 6.050595
# iteration 1000 / 2000: loss 4.716379
# iteration 1100 / 2000: loss 3.770363
# iteration 1200 / 2000: loss 3.148079
# iteration 1300 / 2000: loss 2.668540
# iteration 1400 / 2000: loss 2.559708
# iteration 1500 / 2000: loss 2.311191
# iteration 1600 / 2000: loss 2.191225
# iteration 1700 / 2000: loss 2.099714
# iteration 1800 / 2000: loss 2.103852
# iteration 1900 / 2000: loss 1.969883
# iteration 0 / 2000: loss 311.008095
# iteration 100 / 2000: loss 139.074300
# iteration 200 / 2000: loss 63.210090
# iteration 300 / 2000: loss 29.367163
# iteration 400 / 2000: loss 14.244738
# iteration 500 / 2000: loss 7.458026
# iteration 600 / 2000: loss 4.527145
# iteration 700 / 2000: loss 3.124668
# iteration 800 / 2000: loss 2.478559
# iteration 900 / 2000: loss 2.232153
# iteration 1000 / 2000: loss 2.054239
# iteration 1100 / 2000: loss 2.061201
# iteration 1200 / 2000: loss 2.006366
# iteration 1300 / 2000: loss 2.051560
# iteration 1400 / 2000: loss 1.945846
# iteration 1500 / 2000: loss 2.059164
# iteration 1600 / 2000: loss 2.018485
# iteration 1700 / 2000: loss 1.971563
# iteration 1800 / 2000: loss 2.014572
# iteration 1900 / 2000: loss 2.004862
# iteration 0 / 2000: loss 464.892974
# iteration 100 / 2000: loss 139.706237
# iteration 200 / 2000: loss 43.116606
# iteration 300 / 2000: loss 14.352465
# iteration 400 / 2000: loss 5.710176
# iteration 500 / 2000: loss 3.129482
# iteration 600 / 2000: loss 2.391343
# iteration 700 / 2000: loss 2.120866
# iteration 800 / 2000: loss 2.055288
# iteration 900 / 2000: loss 1.999816
# iteration 1000 / 2000: loss 2.032105
# iteration 1100 / 2000: loss 2.053875
# iteration 1200 / 2000: loss 2.001514
# iteration 1300 / 2000: loss 2.010639
# iteration 1400 / 2000: loss 2.077148
# iteration 1500 / 2000: loss 2.008250
# iteration 1600 / 2000: loss 2.046862
# iteration 1700 / 2000: loss 2.046444
# iteration 1800 / 2000: loss 2.033864
# iteration 1900 / 2000: loss 2.080674
# iteration 0 / 2000: loss 626.813944
# iteration 100 / 2000: loss 126.479742
# iteration 200 / 2000: loss 26.862098
# iteration 300 / 2000: loss 7.006864
# iteration 400 / 2000: loss 2.974216
# iteration 500 / 2000: loss 2.258754
# iteration 600 / 2000: loss 2.140981
# iteration 700 / 2000: loss 2.070628
# iteration 800 / 2000: loss 2.114594
# iteration 900 / 2000: loss 2.125402
# iteration 1000 / 2000: loss 2.080531
# iteration 1100 / 2000: loss 2.024693
# iteration 1200 / 2000: loss 2.035856
# iteration 1300 / 2000: loss 2.105832
# iteration 1400 / 2000: loss 2.078290
# iteration 1500 / 2000: loss 2.075141
# iteration 1600 / 2000: loss 2.095218
# iteration 1700 / 2000: loss 2.062048
# iteration 1800 / 2000: loss 2.127040
# iteration 1900 / 2000: loss 2.045159
# iteration 0 / 2000: loss 767.839083
# iteration 100 / 2000: loss 103.996510
# iteration 200 / 2000: loss 15.825087
# iteration 300 / 2000: loss 3.872697
# iteration 400 / 2000: loss 2.341683
# iteration 500 / 2000: loss 2.135172
# iteration 600 / 2000: loss 2.135927
# iteration 700 / 2000: loss 2.112770
# iteration 800 / 2000: loss 2.111085
# iteration 900 / 2000: loss 2.145397
# iteration 1000 / 2000: loss 2.044038
# iteration 1100 / 2000: loss 2.068183
# iteration 1200 / 2000: loss 2.077139
# iteration 1300 / 2000: loss 2.037469
# iteration 1400 / 2000: loss 2.113137
# iteration 1500 / 2000: loss 2.082257
# iteration 1600 / 2000: loss 2.080357
# iteration 1700 / 2000: loss 2.057788
# iteration 1800 / 2000: loss 2.063209
# iteration 1900 / 2000: loss 2.093072
# iteration 0 / 2000: loss 919.227735
# iteration 100 / 2000: loss 83.485222
# iteration 200 / 2000: loss 9.354741
# iteration 300 / 2000: loss 2.724011
# iteration 400 / 2000: loss 2.157074
# iteration 500 / 2000: loss 2.135943
# iteration 600 / 2000: loss 2.138371
# iteration 700 / 2000: loss 2.016661
# iteration 800 / 2000: loss 2.104403
# iteration 900 / 2000: loss 2.090761
# iteration 1000 / 2000: loss 2.127696
# iteration 1100 / 2000: loss 2.081587
# iteration 1200 / 2000: loss 2.121654
# iteration 1300 / 2000: loss 2.139353
# iteration 1400 / 2000: loss 2.067517
# iteration 1500 / 2000: loss 2.124042
# iteration 1600 / 2000: loss 2.024823
# iteration 1700 / 2000: loss 2.066719
# iteration 1800 / 2000: loss 2.090417
# iteration 1900 / 2000: loss 2.066575
# iteration 0 / 2000: loss 1083.092656
# iteration 100 / 2000: loss 66.166342
# iteration 200 / 2000: loss 5.889798
# iteration 300 / 2000: loss 2.365586
# iteration 400 / 2000: loss 2.092873
# iteration 500 / 2000: loss 2.139008
# iteration 600 / 2000: loss 2.139530
# iteration 700 / 2000: loss 2.095763
# iteration 800 / 2000: loss 2.047341
# iteration 900 / 2000: loss 2.161891
# iteration 1000 / 2000: loss 2.111141
# iteration 1100 / 2000: loss 2.119338
# iteration 1200 / 2000: loss 2.126908
# iteration 1300 / 2000: loss 2.085725
# iteration 1400 / 2000: loss 2.082187
# iteration 1500 / 2000: loss 2.114456
# iteration 1600 / 2000: loss 2.096211
# iteration 1700 / 2000: loss 2.085459
# iteration 1800 / 2000: loss 2.074636
# iteration 1900 / 2000: loss 2.115017
# iteration 0 / 2000: loss 1255.055681
# iteration 100 / 2000: loss 51.593614
# iteration 200 / 2000: loss 4.099129
# iteration 300 / 2000: loss 2.188579
# iteration 400 / 2000: loss 2.132423
# iteration 500 / 2000: loss 2.115866
# iteration 600 / 2000: loss 2.140419
# iteration 700 / 2000: loss 2.062290
# iteration 800 / 2000: loss 2.137634
# iteration 900 / 2000: loss 2.132091
# iteration 1000 / 2000: loss 2.162505
# iteration 1100 / 2000: loss 2.143363
# iteration 1200 / 2000: loss 2.122655
# iteration 1300 / 2000: loss 2.133865
# iteration 1400 / 2000: loss 2.126877
# iteration 1500 / 2000: loss 2.068566
# iteration 1600 / 2000: loss 2.154921
# iteration 1700 / 2000: loss 2.095925
# iteration 1800 / 2000: loss 2.078969
# iteration 1900 / 2000: loss 2.092430
# iteration 0 / 2000: loss 1534.902412
# iteration 100 / 2000: loss 28.894560
# iteration 200 / 2000: loss 2.651201
# iteration 300 / 2000: loss 2.139818
# iteration 400 / 2000: loss 2.161341
# iteration 500 / 2000: loss 2.164275
# iteration 600 / 2000: loss 2.131909
# iteration 700 / 2000: loss 2.117321
# iteration 800 / 2000: loss 2.200625
# iteration 900 / 2000: loss 2.141880
# iteration 1000 / 2000: loss 2.145152
# iteration 1100 / 2000: loss 2.135361
# iteration 1200 / 2000: loss 2.125437
# iteration 1300 / 2000: loss 2.137235
# iteration 1400 / 2000: loss 2.132640
# iteration 1500 / 2000: loss 2.140716
# iteration 1600 / 2000: loss 2.183390
# iteration 1700 / 2000: loss 2.163987
# iteration 1800 / 2000: loss 2.172679
# iteration 1900 / 2000: loss 2.168901
# iteration 0 / 2000: loss 159.396009
# iteration 100 / 2000: loss 86.257460
# iteration 200 / 2000: loss 47.610692
# iteration 300 / 2000: loss 26.834046
# iteration 400 / 2000: loss 15.514436
# iteration 500 / 2000: loss 9.405256
# iteration 600 / 2000: loss 5.978912
# iteration 700 / 2000: loss 4.201643
# iteration 800 / 2000: loss 3.212667
# iteration 900 / 2000: loss 2.580364
# iteration 1000 / 2000: loss 2.306876
# iteration 1100 / 2000: loss 2.075275
# iteration 1200 / 2000: loss 2.053686
# iteration 1300 / 2000: loss 2.010584
# iteration 1400 / 2000: loss 1.931174
# iteration 1500 / 2000: loss 1.997940
# iteration 1600 / 2000: loss 1.952438
# iteration 1700 / 2000: loss 1.828497
# iteration 1800 / 2000: loss 1.887123
# iteration 1900 / 2000: loss 1.948118
# iteration 0 / 2000: loss 315.614889
# iteration 100 / 2000: loss 94.924508
# iteration 200 / 2000: loss 29.687763
# iteration 300 / 2000: loss 10.339341
# iteration 400 / 2000: loss 4.463752
# iteration 500 / 2000: loss 2.796012
# iteration 600 / 2000: loss 2.207112
# iteration 700 / 2000: loss 2.056848
# iteration 800 / 2000: loss 2.043277
# iteration 900 / 2000: loss 2.052239
# iteration 1000 / 2000: loss 2.043439
# iteration 1100 / 2000: loss 1.987823
# iteration 1200 / 2000: loss 1.927131
# iteration 1300 / 2000: loss 1.965183
# iteration 1400 / 2000: loss 1.983547
# iteration 1500 / 2000: loss 1.992961
# iteration 1600 / 2000: loss 1.970535
# iteration 1700 / 2000: loss 1.983183
# iteration 1800 / 2000: loss 1.966342
# iteration 1900 / 2000: loss 1.990517
# iteration 0 / 2000: loss 463.449532
# iteration 100 / 2000: loss 76.986920
# iteration 200 / 2000: loss 14.275025
# iteration 300 / 2000: loss 4.012610
# iteration 400 / 2000: loss 2.380025
# iteration 500 / 2000: loss 2.072638
# iteration 600 / 2000: loss 2.079697
# iteration 700 / 2000: loss 2.011190
# iteration 800 / 2000: loss 2.057039
# iteration 900 / 2000: loss 2.037975
# iteration 1000 / 2000: loss 2.023137
# iteration 1100 / 2000: loss 2.100106
# iteration 1200 / 2000: loss 2.071237
# iteration 1300 / 2000: loss 2.032846
# iteration 1400 / 2000: loss 2.025578
# iteration 1500 / 2000: loss 2.012161
# iteration 1600 / 2000: loss 2.022616
# iteration 1700 / 2000: loss 2.071767
# iteration 1800 / 2000: loss 2.061565
# iteration 1900 / 2000: loss 2.018600
# iteration 0 / 2000: loss 619.514268
# iteration 100 / 2000: loss 56.693685
# iteration 200 / 2000: loss 6.875573
# iteration 300 / 2000: loss 2.494117
# iteration 400 / 2000: loss 2.107866
# iteration 500 / 2000: loss 2.128523
# iteration 600 / 2000: loss 2.093975
# iteration 700 / 2000: loss 2.042987
# iteration 800 / 2000: loss 2.080654
# iteration 900 / 2000: loss 2.062035
# iteration 1000 / 2000: loss 2.064618
# iteration 1100 / 2000: loss 2.098901
# iteration 1200 / 2000: loss 2.148463
# iteration 1300 / 2000: loss 2.131492
# iteration 1400 / 2000: loss 2.086277
# iteration 1500 / 2000: loss 2.083731
# iteration 1600 / 2000: loss 2.045711
# iteration 1700 / 2000: loss 2.033132
# iteration 1800 / 2000: loss 2.130867
# iteration 1900 / 2000: loss 2.079769
# iteration 0 / 2000: loss 778.779147
# iteration 100 / 2000: loss 39.554674
# iteration 200 / 2000: loss 3.906008
# iteration 300 / 2000: loss 2.100293
# iteration 400 / 2000: loss 2.063749
# iteration 500 / 2000: loss 2.096330
# iteration 600 / 2000: loss 2.117782
# iteration 700 / 2000: loss 2.049328
# iteration 800 / 2000: loss 2.129637
# iteration 900 / 2000: loss 2.098045
# iteration 1000 / 2000: loss 2.104182
# iteration 1100 / 2000: loss 2.091608
# iteration 1200 / 2000: loss 2.051574
# iteration 1300 / 2000: loss 2.035473
# iteration 1400 / 2000: loss 2.132493
# iteration 1500 / 2000: loss 2.043738
# iteration 1600 / 2000: loss 2.078285
# iteration 1700 / 2000: loss 2.104990
# iteration 1800 / 2000: loss 2.108809
# iteration 1900 / 2000: loss 2.136867
# iteration 0 / 2000: loss 927.014148
# iteration 100 / 2000: loss 26.327696
# iteration 200 / 2000: loss 2.764833
# iteration 300 / 2000: loss 2.081738
# iteration 400 / 2000: loss 2.095371
# iteration 500 / 2000: loss 2.089769
# iteration 600 / 2000: loss 2.099430
# iteration 700 / 2000: loss 2.086429
# iteration 800 / 2000: loss 2.174990
# iteration 900 / 2000: loss 2.086126
# iteration 1000 / 2000: loss 2.125249
# iteration 1100 / 2000: loss 2.091129
# iteration 1200 / 2000: loss 2.102936
# iteration 1300 / 2000: loss 2.105461
# iteration 1400 / 2000: loss 2.109941
# iteration 1500 / 2000: loss 2.088825
# iteration 1600 / 2000: loss 2.081723
# iteration 1700 / 2000: loss 2.084883
# iteration 1800 / 2000: loss 2.130597
# iteration 1900 / 2000: loss 2.128435
# iteration 0 / 2000: loss 1103.465073
# iteration 100 / 2000: loss 17.757229
# iteration 200 / 2000: loss 2.313318
# iteration 300 / 2000: loss 2.068859
# iteration 400 / 2000: loss 2.128859
# iteration 500 / 2000: loss 2.083736
# iteration 600 / 2000: loss 2.154265
# iteration 700 / 2000: loss 2.122829
# iteration 800 / 2000: loss 2.147513
# iteration 900 / 2000: loss 2.132252
# iteration 1000 / 2000: loss 2.123245
# iteration 1100 / 2000: loss 2.140281
# iteration 1200 / 2000: loss 2.112789
# iteration 1300 / 2000: loss 2.113125
# iteration 1400 / 2000: loss 2.116436
# iteration 1500 / 2000: loss 2.135923
# iteration 1600 / 2000: loss 2.107867
# iteration 1700 / 2000: loss 2.138319
# iteration 1800 / 2000: loss 2.108277
# iteration 1900 / 2000: loss 2.087450
# iteration 0 / 2000: loss 1247.481922
# iteration 100 / 2000: loss 11.693280
# iteration 200 / 2000: loss 2.189828
# iteration 300 / 2000: loss 2.086096
# iteration 400 / 2000: loss 2.113601
# iteration 500 / 2000: loss 2.087531
# iteration 600 / 2000: loss 2.151028
# iteration 700 / 2000: loss 2.127335
# iteration 800 / 2000: loss 2.141388
# iteration 900 / 2000: loss 2.129181
# iteration 1000 / 2000: loss 2.170219
# iteration 1100 / 2000: loss 2.141206
# iteration 1200 / 2000: loss 2.142891
# iteration 1300 / 2000: loss 2.057777
# iteration 1400 / 2000: loss 2.103291
# iteration 1500 / 2000: loss 2.134621
# iteration 1600 / 2000: loss 2.128342
# iteration 1700 / 2000: loss 2.141796
# iteration 1800 / 2000: loss 2.147696
# iteration 1900 / 2000: loss 2.132551
# iteration 0 / 2000: loss 1523.274042
# iteration 100 / 2000: loss 5.596432
# iteration 200 / 2000: loss 2.115613
# iteration 300 / 2000: loss 2.097270
# iteration 400 / 2000: loss 2.121734
# iteration 500 / 2000: loss 2.116524
# iteration 600 / 2000: loss 2.162259
# iteration 700 / 2000: loss 2.158283
# iteration 800 / 2000: loss 2.142523
# iteration 900 / 2000: loss 2.138448
# iteration 1000 / 2000: loss 2.153015
# iteration 1100 / 2000: loss 2.190698
# iteration 1200 / 2000: loss 2.162818
# iteration 1300 / 2000: loss 2.137332
# iteration 1400 / 2000: loss 2.103879
# iteration 1500 / 2000: loss 2.119720
# iteration 1600 / 2000: loss 2.098019
# iteration 1700 / 2000: loss 2.142592
# iteration 1800 / 2000: loss 2.175755
# iteration 1900 / 2000: loss 2.159736
# iteration 0 / 2000: loss 159.781833
# iteration 100 / 2000: loss 28.103672
# iteration 200 / 2000: loss 41.760896
# iteration 300 / 2000: loss 30.812872
# iteration 400 / 2000: loss 48.354995
# iteration 500 / 2000: loss 31.079677
# iteration 600 / 2000: loss 48.579137
# iteration 700 / 2000: loss 54.706577
# iteration 800 / 2000: loss 30.083136
# iteration 900 / 2000: loss 46.552356
# iteration 1000 / 2000: loss 50.959566
# iteration 1100 / 2000: loss 26.791399
# iteration 1200 / 2000: loss 25.884447
# iteration 1300 / 2000: loss 38.170365
# iteration 1400 / 2000: loss 41.730576
# iteration 1500 / 2000: loss 44.121090
# iteration 1600 / 2000: loss 37.403862
# iteration 1700 / 2000: loss 37.589467
# iteration 1800 / 2000: loss 45.036856
# iteration 1900 / 2000: loss 36.924919
# iteration 0 / 2000: loss 310.778370
# iteration 100 / 2000: loss 96.679280
# iteration 200 / 2000: loss 75.613495
# iteration 300 / 2000: loss 87.792812
# iteration 400 / 2000: loss 82.585717
# iteration 500 / 2000: loss 90.119261
# iteration 600 / 2000: loss 88.909934
# iteration 700 / 2000: loss 75.306254
# iteration 800 / 2000: loss 82.877965
# iteration 900 / 2000: loss 69.516555
# iteration 1000 / 2000: loss 73.474701
# iteration 1100 / 2000: loss 108.209129
# iteration 1200 / 2000: loss 77.246854
# iteration 1300 / 2000: loss 86.548944
# iteration 1400 / 2000: loss 81.601666
# iteration 1500 / 2000: loss 69.221629
# iteration 1600 / 2000: loss 68.429257
# iteration 1700 / 2000: loss 77.091852
# iteration 1800 / 2000: loss 90.996316
# iteration 1900 / 2000: loss 85.047162
# iteration 0 / 2000: loss 461.732444
# iteration 100 / 2000: loss 268.199362
# iteration 200 / 2000: loss inf
# iteration 300 / 2000: loss 275.023543
# iteration 400 / 2000: loss 310.514307
# iteration 500 / 2000: loss 282.812560
# iteration 600 / 2000: loss 276.027717
# iteration 700 / 2000: loss 284.813778
# iteration 800 / 2000: loss 309.438436
# iteration 900 / 2000: loss 283.974956
# iteration 1000 / 2000: loss 264.157440
# iteration 1100 / 2000: loss 283.682383
# iteration 1200 / 2000: loss 262.203922
# iteration 1300 / 2000: loss 292.136310
# iteration 1400 / 2000: loss inf
# iteration 1500 / 2000: loss 313.176856
# iteration 1600 / 2000: loss 274.604036
# iteration 1700 / 2000: loss 271.540687
# iteration 1800 / 2000: loss 295.068798
# iteration 1900 / 2000: loss 303.558415
# iteration 0 / 2000: loss 618.324267
# iteration 100 / 2000: loss nan
# iteration 200 / 2000: loss nan
# iteration 300 / 2000: loss nan
# iteration 400 / 2000: loss nan
# iteration 500 / 2000: loss nan
# iteration 600 / 2000: loss nan
# iteration 700 / 2000: loss nan
# iteration 800 / 2000: loss nan
# iteration 900 / 2000: loss nan
# iteration 1000 / 2000: loss nan
# iteration 1100 / 2000: loss nan
# iteration 1200 / 2000: loss nan
# iteration 1300 / 2000: loss nan
# iteration 1400 / 2000: loss nan
# iteration 1500 / 2000: loss nan
# iteration 1600 / 2000: loss nan
# iteration 1700 / 2000: loss nan
# iteration 1800 / 2000: loss nan
# iteration 1900 / 2000: loss nan
# iteration 0 / 2000: loss 763.186009
# iteration 100 / 2000: loss nan
# iteration 200 / 2000: loss nan
# iteration 300 / 2000: loss nan
# iteration 400 / 2000: loss nan
# iteration 500 / 2000: loss nan
# iteration 600 / 2000: loss nan
# iteration 700 / 2000: loss nan
# iteration 800 / 2000: loss nan
# iteration 900 / 2000: loss nan
# iteration 1000 / 2000: loss nan
# iteration 1100 / 2000: loss nan
# iteration 1200 / 2000: loss nan
# iteration 1300 / 2000: loss nan
# iteration 1400 / 2000: loss nan
# iteration 1500 / 2000: loss nan
# iteration 1600 / 2000: loss nan
# iteration 1700 / 2000: loss nan
# iteration 1800 / 2000: loss nan
# iteration 1900 / 2000: loss nan
# iteration 0 / 2000: loss 926.898359
# iteration 100 / 2000: loss nan
# iteration 200 / 2000: loss nan
# iteration 300 / 2000: loss nan
# iteration 400 / 2000: loss nan
# iteration 500 / 2000: loss nan
# iteration 600 / 2000: loss nan
# iteration 700 / 2000: loss nan
# iteration 800 / 2000: loss nan
# iteration 900 / 2000: loss nan
# iteration 1000 / 2000: loss nan
# iteration 1100 / 2000: loss nan
# iteration 1200 / 2000: loss nan
# iteration 1300 / 2000: loss nan
# iteration 1400 / 2000: loss nan
# iteration 1500 / 2000: loss nan
# iteration 1600 / 2000: loss nan
# iteration 1700 / 2000: loss nan
# iteration 1800 / 2000: loss nan
# iteration 1900 / 2000: loss nan
# iteration 0 / 2000: loss 1100.173547
# iteration 100 / 2000: loss nan
# iteration 200 / 2000: loss nan
# iteration 300 / 2000: loss nan
# iteration 400 / 2000: loss nan
# iteration 500 / 2000: loss nan
# iteration 600 / 2000: loss nan
# iteration 700 / 2000: loss nan
# iteration 800 / 2000: loss nan
# iteration 900 / 2000: loss nan
# iteration 1000 / 2000: loss nan
# iteration 1100 / 2000: loss nan
# iteration 1200 / 2000: loss nan
# iteration 1300 / 2000: loss nan
# iteration 1400 / 2000: loss nan
# iteration 1500 / 2000: loss nan
# iteration 1600 / 2000: loss nan
# iteration 1700 / 2000: loss nan
# iteration 1800 / 2000: loss nan
# iteration 1900 / 2000: loss nan
# iteration 0 / 2000: loss 1224.529131
# iteration 100 / 2000: loss nan
# iteration 200 / 2000: loss nan
# iteration 300 / 2000: loss nan
# iteration 400 / 2000: loss nan
# iteration 500 / 2000: loss nan
# iteration 600 / 2000: loss nan
# iteration 700 / 2000: loss nan
# iteration 800 / 2000: loss nan
# iteration 900 / 2000: loss nan
# iteration 1000 / 2000: loss nan
# iteration 1100 / 2000: loss nan
# iteration 1200 / 2000: loss nan
# iteration 1300 / 2000: loss nan
# iteration 1400 / 2000: loss nan
# iteration 1500 / 2000: loss nan
# iteration 1600 / 2000: loss nan
# iteration 1700 / 2000: loss nan
# iteration 1800 / 2000: loss nan
# iteration 1900 / 2000: loss nan
# iteration 0 / 2000: loss 1530.502118
# iteration 100 / 2000: loss nan
# iteration 200 / 2000: loss nan
# iteration 300 / 2000: loss nan
# iteration 400 / 2000: loss nan
# iteration 500 / 2000: loss nan
# iteration 600 / 2000: loss nan
# iteration 700 / 2000: loss nan
# iteration 800 / 2000: loss nan
# iteration 900 / 2000: loss nan
# iteration 1000 / 2000: loss nan
# iteration 1100 / 2000: loss nan
# iteration 1200 / 2000: loss nan
# iteration 1300 / 2000: loss nan
# iteration 1400 / 2000: loss nan
# iteration 1500 / 2000: loss nan
# iteration 1600 / 2000: loss nan
# iteration 1700 / 2000: loss nan
# iteration 1800 / 2000: loss nan
# iteration 1900 / 2000: loss nan
# iteration 0 / 2000: loss 159.319187
# iteration 100 / 2000: loss 32.807757
# iteration 200 / 2000: loss 8.097430
# iteration 300 / 2000: loss 3.170078
# iteration 400 / 2000: loss 2.169074
# iteration 500 / 2000: loss 2.030885
# iteration 600 / 2000: loss 2.142472
# iteration 700 / 2000: loss 1.993258
# iteration 800 / 2000: loss 1.956428
# iteration 900 / 2000: loss 1.971209
# iteration 1000 / 2000: loss 1.959980
# iteration 1100 / 2000: loss 1.884195
# iteration 1200 / 2000: loss 1.942675
# iteration 1300 / 2000: loss 1.925156
# iteration 1400 / 2000: loss 1.972502
# iteration 1500 / 2000: loss 2.008818
# iteration 1600 / 2000: loss 1.807453
# iteration 1700 / 2000: loss 1.975201
# iteration 1800 / 2000: loss 1.930090
# iteration 1900 / 2000: loss 1.941977
# iteration 0 / 2000: loss 310.506175
# iteration 100 / 2000: loss 13.936722
# iteration 200 / 2000: loss 2.485117
# iteration 300 / 2000: loss 2.094856
# iteration 400 / 2000: loss 1.981974
# iteration 500 / 2000: loss 2.031287
# iteration 600 / 2000: loss 1.995252
# iteration 700 / 2000: loss 1.962949
# iteration 800 / 2000: loss 2.028054
# iteration 900 / 2000: loss 2.067299
# iteration 1000 / 2000: loss 2.035219
# iteration 1100 / 2000: loss 1.989450
# iteration 1200 / 2000: loss 1.957857
# iteration 1300 / 2000: loss 1.926011
# iteration 1400 / 2000: loss 1.962206
# iteration 1500 / 2000: loss 2.000648
# iteration 1600 / 2000: loss 2.049150
# iteration 1700 / 2000: loss 2.031251
# iteration 1800 / 2000: loss 1.943796
# iteration 1900 / 2000: loss 2.033963
# iteration 0 / 2000: loss 474.233069
# iteration 100 / 2000: loss 5.607426
# iteration 200 / 2000: loss 2.080758
# iteration 300 / 2000: loss 2.025571
# iteration 400 / 2000: loss 2.097956
# iteration 500 / 2000: loss 2.103837
# iteration 600 / 2000: loss 1.977459
# iteration 700 / 2000: loss 2.055807
# iteration 800 / 2000: loss 2.087982
# iteration 900 / 2000: loss 1.975428
# iteration 1000 / 2000: loss 2.037719
# iteration 1100 / 2000: loss 2.058206
# iteration 1200 / 2000: loss 1.981311
# iteration 1300 / 2000: loss 1.985425
# iteration 1400 / 2000: loss 2.029298
# iteration 1500 / 2000: loss 2.047273
# iteration 1600 / 2000: loss 2.114397
# iteration 1700 / 2000: loss 2.027511
# iteration 1800 / 2000: loss 2.002568
# iteration 1900 / 2000: loss 2.132087
# iteration 0 / 2000: loss 629.235064
# iteration 100 / 2000: loss 2.954219
# iteration 200 / 2000: loss 2.128371
# iteration 300 / 2000: loss 2.155578
# iteration 400 / 2000: loss 2.081012
# iteration 500 / 2000: loss 2.020333
# iteration 600 / 2000: loss 2.057304
# iteration 700 / 2000: loss 2.089303
# iteration 800 / 2000: loss 2.111456
# iteration 900 / 2000: loss 2.162059
# iteration 1000 / 2000: loss 2.152400
# iteration 1100 / 2000: loss 2.093185
# iteration 1200 / 2000: loss 2.114293
# iteration 1300 / 2000: loss 2.081891
# iteration 1400 / 2000: loss 2.112900
# iteration 1500 / 2000: loss 2.062261
# iteration 1600 / 2000: loss 2.117955
# iteration 1700 / 2000: loss 2.072885
# iteration 1800 / 2000: loss 2.122485
# iteration 1900 / 2000: loss 2.060614
# iteration 0 / 2000: loss 774.830736
# iteration 100 / 2000: loss 2.339430
# iteration 200 / 2000: loss 2.103745
# iteration 300 / 2000: loss 2.106332
# iteration 400 / 2000: loss 2.114790
# iteration 500 / 2000: loss 2.078766
# iteration 600 / 2000: loss 2.073584
# iteration 700 / 2000: loss 2.130938
# iteration 800 / 2000: loss 2.047174
# iteration 900 / 2000: loss 2.082194
# iteration 1000 / 2000: loss 2.096717
# iteration 1100 / 2000: loss 2.081231
# iteration 1200 / 2000: loss 2.125370
# iteration 1300 / 2000: loss 2.081454
# iteration 1400 / 2000: loss 2.131297
# iteration 1500 / 2000: loss 2.132212
# iteration 1600 / 2000: loss 2.123250
# iteration 1700 / 2000: loss 2.097028
# iteration 1800 / 2000: loss 2.090028
# iteration 1900 / 2000: loss 2.056873
# iteration 0 / 2000: loss 922.554063
# iteration 100 / 2000: loss 2.180970
# iteration 200 / 2000: loss 2.108373
# iteration 300 / 2000: loss 2.082117
# iteration 400 / 2000: loss 2.104886
# iteration 500 / 2000: loss 2.112082
# iteration 600 / 2000: loss 2.174367
# iteration 700 / 2000: loss 2.143729
# iteration 800 / 2000: loss 2.080428
# iteration 900 / 2000: loss 2.146302
# iteration 1000 / 2000: loss 2.160697
# iteration 1100 / 2000: loss 2.122919
# iteration 1200 / 2000: loss 2.083963
# iteration 1300 / 2000: loss 2.054640
# iteration 1400 / 2000: loss 2.059014
# iteration 1500 / 2000: loss 2.131189
# iteration 1600 / 2000: loss 2.153563
# iteration 1700 / 2000: loss 2.070468
# iteration 1800 / 2000: loss 2.075896
# iteration 1900 / 2000: loss 2.080707
# iteration 0 / 2000: loss 1071.071125
# iteration 100 / 2000: loss 2.132744
# iteration 200 / 2000: loss 2.141661
# iteration 300 / 2000: loss 2.134489
# iteration 400 / 2000: loss 2.097685
# iteration 500 / 2000: loss 2.133366
# iteration 600 / 2000: loss 2.105381
# iteration 700 / 2000: loss 2.106860
# iteration 800 / 2000: loss 2.111995
# iteration 900 / 2000: loss 2.142840
# iteration 1000 / 2000: loss 2.120667
# iteration 1100 / 2000: loss 2.128170
# iteration 1200 / 2000: loss 2.109728
# iteration 1300 / 2000: loss 2.115412
# iteration 1400 / 2000: loss 2.087258
# iteration 1500 / 2000: loss 2.064060
# iteration 1600 / 2000: loss 2.139034
# iteration 1700 / 2000: loss 2.110394
# iteration 1800 / 2000: loss 2.114530
# iteration 1900 / 2000: loss 2.129350
# iteration 0 / 2000: loss 1240.579529
# iteration 100 / 2000: loss 2.148410
# iteration 200 / 2000: loss 2.122222
# iteration 300 / 2000: loss 2.149040
# iteration 400 / 2000: loss 2.144397
# iteration 500 / 2000: loss 2.097757
# iteration 600 / 2000: loss 2.147291
# iteration 700 / 2000: loss 2.127293
# iteration 800 / 2000: loss 2.166958
# iteration 900 / 2000: loss 2.156851
# iteration 1000 / 2000: loss 2.110266
# iteration 1100 / 2000: loss 2.140182
# iteration 1200 / 2000: loss 2.120831
# iteration 1300 / 2000: loss 2.120657
# iteration 1400 / 2000: loss 2.197350
# iteration 1500 / 2000: loss 2.107478
# iteration 1600 / 2000: loss 2.139539
# iteration 1700 / 2000: loss 2.088364
# iteration 1800 / 2000: loss 2.143587
# iteration 1900 / 2000: loss 2.124416
# iteration 0 / 2000: loss 1559.987644
# iteration 100 / 2000: loss 2.129526
# iteration 200 / 2000: loss 2.201654
# iteration 300 / 2000: loss 2.156674
# iteration 400 / 2000: loss 2.154479
# iteration 500 / 2000: loss 2.135744
# iteration 600 / 2000: loss 2.116273
# iteration 700 / 2000: loss 2.183660
# iteration 800 / 2000: loss 2.154309
# iteration 900 / 2000: loss 2.116941
# iteration 1000 / 2000: loss 2.124261
# iteration 1100 / 2000: loss 2.199251
# iteration 1200 / 2000: loss 2.120049
# iteration 1300 / 2000: loss 2.122409
# iteration 1400 / 2000: loss 2.170569
# iteration 1500 / 2000: loss 2.156123
# iteration 1600 / 2000: loss 2.237233
# iteration 1700 / 2000: loss 2.160069
# iteration 1800 / 2000: loss 2.129535
# iteration 1900 / 2000: loss 2.142235
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.355367 val accuracy: 0.365000
# lr 1.000000e-07 reg 2.000000e+04 train accuracy: 0.357429 val accuracy: 0.378000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.347551 val accuracy: 0.359000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.333592 val accuracy: 0.349000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.329959 val accuracy: 0.347000
# lr 1.000000e-07 reg 6.000000e+04 train accuracy: 0.318490 val accuracy: 0.334000
# lr 1.000000e-07 reg 7.000000e+04 train accuracy: 0.314837 val accuracy: 0.332000
# lr 1.000000e-07 reg 8.000000e+04 train accuracy: 0.318265 val accuracy: 0.333000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.304918 val accuracy: 0.318000
# lr 2.000000e-07 reg 1.000000e+04 train accuracy: 0.377041 val accuracy: 0.398000
# lr 2.000000e-07 reg 2.000000e+04 train accuracy: 0.354490 val accuracy: 0.371000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.348306 val accuracy: 0.354000
# lr 2.000000e-07 reg 4.000000e+04 train accuracy: 0.334306 val accuracy: 0.337000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.318163 val accuracy: 0.330000
# lr 2.000000e-07 reg 6.000000e+04 train accuracy: 0.321082 val accuracy: 0.333000
# lr 2.000000e-07 reg 7.000000e+04 train accuracy: 0.324735 val accuracy: 0.339000
# lr 2.000000e-07 reg 8.000000e+04 train accuracy: 0.310490 val accuracy: 0.329000
# lr 2.000000e-07 reg 1.000000e+05 train accuracy: 0.298082 val accuracy: 0.311000
# lr 3.000000e-07 reg 1.000000e+04 train accuracy: 0.374204 val accuracy: 0.389000
# lr 3.000000e-07 reg 2.000000e+04 train accuracy: 0.357163 val accuracy: 0.374000
# lr 3.000000e-07 reg 3.000000e+04 train accuracy: 0.342020 val accuracy: 0.356000
# lr 3.000000e-07 reg 4.000000e+04 train accuracy: 0.322939 val accuracy: 0.332000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.324265 val accuracy: 0.332000
# lr 3.000000e-07 reg 6.000000e+04 train accuracy: 0.317714 val accuracy: 0.340000
# lr 3.000000e-07 reg 7.000000e+04 train accuracy: 0.319939 val accuracy: 0.328000
# lr 3.000000e-07 reg 8.000000e+04 train accuracy: 0.314245 val accuracy: 0.330000
# lr 3.000000e-07 reg 1.000000e+05 train accuracy: 0.314224 val accuracy: 0.323000
# lr 8.000000e-07 reg 1.000000e+04 train accuracy: 0.368245 val accuracy: 0.376000
# lr 8.000000e-07 reg 2.000000e+04 train accuracy: 0.355143 val accuracy: 0.355000
# lr 8.000000e-07 reg 3.000000e+04 train accuracy: 0.335490 val accuracy: 0.337000
# lr 8.000000e-07 reg 4.000000e+04 train accuracy: 0.310694 val accuracy: 0.328000
# lr 8.000000e-07 reg 5.000000e+04 train accuracy: 0.329184 val accuracy: 0.336000
# lr 8.000000e-07 reg 6.000000e+04 train accuracy: 0.304837 val accuracy: 0.322000
# lr 8.000000e-07 reg 7.000000e+04 train accuracy: 0.307122 val accuracy: 0.313000
# lr 8.000000e-07 reg 8.000000e+04 train accuracy: 0.305102 val accuracy: 0.324000
# lr 8.000000e-07 reg 1.000000e+05 train accuracy: 0.298857 val accuracy: 0.304000
# lr 5.000000e-05 reg 1.000000e+04 train accuracy: 0.155633 val accuracy: 0.132000
# lr 5.000000e-05 reg 2.000000e+04 train accuracy: 0.071306 val accuracy: 0.064000
# lr 5.000000e-05 reg 3.000000e+04 train accuracy: 0.132592 val accuracy: 0.133000
# lr 5.000000e-05 reg 4.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 6.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 7.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 8.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.398000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.373000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
